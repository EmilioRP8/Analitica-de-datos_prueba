# %%
import json
import pandas as pd
import numpy as np

# %% [markdown]
# **CARGA DE ARCHIVO.CSV EN VISUAL STUDIO CODE (LOCAL)**

# %%
# Convertir a dataframe
victoriabc = pd.read_csv("listings.csv")
victoriabc
# Out:
#                        id                                       listing_url  \
# 0                   19898                https://www.airbnb.com/rooms/19898
# 1                   41168                https://www.airbnb.com/rooms/41168
# 2                   83515                https://www.airbnb.com/rooms/83515
# 3                  168460               https://www.airbnb.com/rooms/168460
# 4                  185732               https://www.airbnb.com/rooms/185732
# ...                   ...                                               ...
# 3946  1315368084757533488  https://www.airbnb.com/rooms/1315368084757533488
# 3947  1316608634341666791  https://www.airbnb.com/rooms/1316608634341666791
# 3948  1317141084646533661  https://www.airbnb.com/rooms/1317141084646533661
# 3949  1318221712246054906  https://www.airbnb.com/rooms/1318221712246054906
# 3950  1318259877390189592  https://www.airbnb.com/rooms/1318259877390189592
#
#          scrape_id last_scraped           source  \
# ...

# %% [markdown]
# **CARGA DE ARCHIVO .XLSX EN VISUAL STUDIO CODE (LOCAL)**

# %%
# %pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#victoriabc = pd.read_excel("Antigüedad de saldos 17.03.2023.xlsx")
#victoriabc

# %% [markdown]
# ***ANÁLISIS EXPLORATORIO DEL DATAFRAME***

# %%
# VERIFICAMOS INFORMACION DEL DATAFRAME 
victoriabc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3951 non-null   int64
#  1   listing_url                                   3951 non-null   object
#  2   scrape_id                                     3951 non-null   float64
#  3   last_scraped                                  3951 non-null   object
#  4   source                                        3951 non-null   object
#  5   name                                          3951 non-null   object
#  6   description                                   3919 non-null   object
#  7   neighborhood_overview                         2321 non-null   object
#  8   picture_url                                   3951 non-null   object
# ...

# %%
#Ajustar maximo de filas
pd.options.display.max_rows = 3

#Extraccion de columnas 
data = victoriabc.iloc[ : , [ 0, 2, 3, 10, 13, 17, 18, 23, 24, 31, 32, 35, 36, 37, 38, 39, 41, 42, 43, 44, 
    45, 46, 47, 48, 49, 52, 53, 54, 55, 57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 
    68, 70, 71, 72, 73, 74, 11, 22, 50, 56, 40
]]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3951 entries, 0 to 3950
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3951 non-null   int64
#  1   scrape_id                                     3951 non-null   float64
#  2   last_scraped                                  3951 non-null   object
#  3   host_url                                      3951 non-null   object
#  4   host_location                                 3179 non-null   object
#  5   host_acceptance_rate                          3553 non-null   object
#  6   host_is_superhost                             3840 non-null   object
#  7   host_total_listings_count                     3951 non-null   int64
#  8   host_verifications                            3951 non-null   object
# ...

# %%
#Convertir archivo a filtrado a df_csv_visual
data.to_csv("Victoria BC.csv")
